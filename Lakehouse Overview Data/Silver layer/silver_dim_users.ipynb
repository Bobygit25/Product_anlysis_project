# %%
import pandas as pd
import numpy as np

# %%
df_users = pd.read_csv(r"C:\Users\ASUS\Documents\College folders\Placements\Projects\Product Analyst\Raw data\raw__users_202607171732.csv")

# %%
df_users
# Out:
#       user_id   account_id        full_name  \
# 0      user_1   account_82    Ingrid Hansen
# 1      user_2   account_26    Ethan Nilsson
# 2      user_3   account_13       Leo Thomas
# 3      user_4   account_25  Lucas Johansson
# 4      user_5   account_27       Lea Bakker
# ..        ...          ...              ...
# 395  user_396   account_79      Emma Wilson
# 396  user_397   account_43       Lina Brown
# 397  user_398  account_114      Leo Nielsen
# 398  user_399   account_91      Adam Bakker
# 399  user_400  account_117     Maja Schmidt
#
#                                    email          job_role user_status  \
# 0              ingrid.hansen@salesops.eu         sales_rep      active
# 1              ethan.nilsson@acme-eu.com         sales_rep      active
# 2                 leo.thomas@salesops.eu     sales_manager      active
# 3            lucas.johansson@acme-eu.com            revops     invited
# 4     lea.bakker@nordicflow-customer.com     sales_manager      active
# ...

# %%
df_users['user_status'] = df_users['user_status'].str.lower()

# %%
date_columns = ['last_seen_at', 'created_at']  # to convert date columns from object to date
df_users[date_columns] = df_users[date_columns].apply(pd.to_datetime)

# %%
df_users['days_last_seen'] = (df_users['last_seen_at'] - pd.Timestamp.now()).dt.days

# %%
df_users['created_at'] = df_users['created_at'].dt.date
df_users['last_seen_at'] = df_users['last_seen_at'].dt.date

# %%
df_users
# Out:
#       user_id   account_id        full_name  \
# 0      user_1   account_82    Ingrid Hansen
# 1      user_2   account_26    Ethan Nilsson
# 2      user_3   account_13       Leo Thomas
# 3      user_4   account_25  Lucas Johansson
# 4      user_5   account_27       Lea Bakker
# ..        ...          ...              ...
# 395  user_396   account_79      Emma Wilson
# 396  user_397   account_43       Lina Brown
# 397  user_398  account_114      Leo Nielsen
# 398  user_399   account_91      Adam Bakker
# 399  user_400  account_117     Maja Schmidt
#
#                                    email          job_role user_status  \
# 0              ingrid.hansen@salesops.eu         sales_rep      active
# 1              ethan.nilsson@acme-eu.com         sales_rep      active
# 2                 leo.thomas@salesops.eu     sales_manager      active
# 3            lucas.johansson@acme-eu.com            revops     invited
# 4     lea.bakker@nordicflow-customer.com     sales_manager      active
# ...

# %%
import mysql.connector as connection
from mysql.connector import Error

mydb = connection.connect(host='localhost',user='root',password='BobySQL2026',database='product_analysis', use_pure=True)

# %%
from sqlalchemy import create_engine
db_credentials = "mysql+pymysql://root:BobySQL2026@localhost:3306/product_analysis"
engine = create_engine(db_credentials)

dim_users = df_users
dim_users.to_sql(
    name = "gold_fact_users",
    con = engine,
    if_exists = 'replace',
    index = False
)
# Out:
# 400
